# %%
import traci
import numpy as np
import matplotlib.pyplot as plt
import random
from collections import deque

# Hyperparameters
ALPHA = 0.1  # Learning rate
GAMMA = 0.95  # Discount factor
EPSILON = 1  # Initial exploration rate
EPSILON_DECAY = 0.01  # Epsilon decay rate
MIN_EPSILON = 0.001  # Minimum exploration rate
NUM_EPISODES = 100
CONVERGENCE_THRESHOLD = 1e-3
REPLAY_BUFFER_SIZE = 1000
BATCH_SIZE = 32

# Initialize Q-table
num_states_traffic = 11
num_states_queue = 11
num_actions = 3
q_table = np.zeros((num_states_traffic, num_states_queue, num_actions))

# Replay buffer for experience replay
replay_buffer = deque(maxlen=REPLAY_BUFFER_SIZE)

# Helper functions
def reset_simulation():
    """Reset the SUMO simulation to the starting point."""
    traci.load(["--net-file", "test1.net.xml", "--route-files", "test1.rou.xml", "--additional-files", "test1.add.xml"])
    return get_state()

def get_state():
    """Retrieve the current state of the system."""
    highway_traffic = min(traci.edge.getLastStepVehicleNumber("E0") / 10, 1)  # Normalize to [0, 1]
    ramp_queue = min(traci.edge.getLastStepVehicleNumber("E2") / 10, 1)  # Normalize to [0, 1]
    traffic_light_phase = traci.trafficlight.getPhase("J1")
    return (highway_traffic, ramp_queue, traffic_light_phase)

def calculate_reward(highway_flow, ramp_queue, avg_speed):
    """Calculate the reward with refined scaling."""
    highway_reward = 10.0 * np.log1p(highway_flow)  # Logarithmic scaling
    speed_reward = 5.0 * avg_speed  # Moderate weight for speed
    queue_penalty = -5.0 * ramp_queue  # Heavier penalty for ramp queue
    reward = highway_reward + speed_reward + queue_penalty
    return reward

def select_action(state, epsilon):
    """Select an action using epsilon-greedy policy with weighted adjustments."""
    if np.random.rand() < epsilon:
        return np.random.choice([0, 1, 2])  # Explore: random action
    else:
        state_indices = (
            max(0, min(int(state[0] * 10), q_table.shape[0] - 1)),
            max(0, min(int(state[1] * 10), q_table.shape[1] - 1)),
            max(0, min(state[2], q_table.shape[2] - 1)),
        )
        q_values = q_table[state_indices[0], state_indices[1], :]
        
        # Debugging: Validate q_values shape
        if q_values.ndim != 1:
            raise ValueError(f"Expected q_values to be 1D, got shape {q_values.shape}. Check state indices: {state_indices}")
        
        weights = [1.2 if i == np.argmax(q_values) else 1.0 for i in range(len(q_values))]
        return random.choices(range(len(q_values)), weights=weights)[0]  # Weighted action selection


def take_action(action):
    """Take the action in the simulation and return the new state and reward."""
    traci.trafficlight.setPhase("J1", action)  # Set traffic light phase

    if traci.simulation.getMinExpectedNumber() > 0:  # Check for active vehicles
        traci.simulationStep()
    else:
        print("No vehicles left, terminating simulation.")
        return None, 0, True  # End episode if no vehicles remain

    # Get new state
    next_state = get_state()
    highway_flow = traci.edge.getLastStepVehicleNumber("E0")
    ramp_queue = traci.edge.getLastStepVehicleNumber("E2")
    avg_speed = traci.edge.getLastStepMeanSpeed("E0")  # Average speed on highway
    reward = calculate_reward(highway_flow, ramp_queue, avg_speed)

    done = False
    return next_state, reward, done

def update_q_table(state, action, reward, next_state):
    """Update the Q-table using the Q-learning formula."""
    if next_state is None:
        return

    state_indices = (
        max(0, min(int(state[0] * 10), q_table.shape[0] - 1)),
        max(0, min(int(state[1] * 10), q_table.shape[1] - 1)),
        max(0, min(state[2], q_table.shape[2] - 1))
    )
    next_state_indices = (
        max(0, min(int(next_state[0] * 10), q_table.shape[0] - 1)),
        max(0, min(int(next_state[1] * 10), q_table.shape[1] - 1)),
        max(0, min(next_state[2], q_table.shape[2] - 1))
    )

    max_future_q = np.max(q_table[next_state_indices[0], next_state_indices[1], :])
    current_q = q_table[state_indices[0], state_indices[1], action]
    q_table[state_indices[0], state_indices[1], action] += ALPHA * (reward + GAMMA * max_future_q - current_q)

def replay_experience():
    """Perform experience replay to stabilize learning."""
    if len(replay_buffer) < BATCH_SIZE:
        return

    batch = random.sample(replay_buffer, BATCH_SIZE)
    for state, action, reward, next_state in batch:
        update_q_table(state, action, reward, next_state)

# Run simulation
sumo_binary = "sumo"
sumo_config_file = "test1.sumocfg"
traci.start([sumo_binary, "-c", sumo_config_file])

# Run Simulation with Improved Exploration and Exploitation
cumulative_rewards = []
highway_flows = []
ramp_queues = []
avg_speeds = []

for episode in range(NUM_EPISODES):
    print(f"Starting episode {episode + 1}")
    total_reward = 0
    state = reset_simulation()
    done = False

    q_table_prev = q_table.copy()  # Copy for convergence check
    episode_highway_flows = []
    episode_ramp_queues = []
    episode_speeds = []

    while not done:
        if state is None:
            done = True
            break

        action = select_action(state, EPSILON)
        next_state, reward, done = take_action(action)
        total_reward += reward

        if next_state is None:
            done = True
            break

        replay_buffer.append((state, action, reward, next_state))
        update_q_table(state, action, reward, next_state)
        state = next_state

        # Track metrics
        highway_flow = traci.edge.getLastStepVehicleNumber("E0")
        ramp_queue = traci.edge.getLastStepVehicleNumber("E2")
        avg_speed = traci.edge.getLastStepMeanSpeed("E0")
        episode_highway_flows.append(highway_flow)
        episode_ramp_queues.append(ramp_queue)
        episode_speeds.append(avg_speed)

        replay_experience()  # Perform experience replay

    # Aggregate metrics for the episode
    highway_flows.append(np.mean(episode_highway_flows))
    ramp_queues.append(np.mean(episode_ramp_queues))
    avg_speeds.append(np.mean(episode_speeds))

    # Convergence Check
    max_change = np.max(np.abs(q_table - q_table_prev))
    if max_change < CONVERGENCE_THRESHOLD:
        print(f"Convergence reached at episode {episode + 1} (Q-table change: {max_change:.6f})")
        break

    # Decay Epsilon
    EPSILON = max(MIN_EPSILON, EPSILON * (1 - EPSILON_DECAY))

    cumulative_rewards.append(total_reward)
    print(f"Episode {episode + 1} finished with total reward: {total_reward:.2f}")

traci.close()

# Plot Results
plt.figure(figsize=(14, 8))

# Cumulative Rewards
plt.subplot(2, 2, 1)
plt.plot(cumulative_rewards, label="Cumulative Rewards")
plt.title("Cumulative Rewards Over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Cumulative Reward")
plt.legend()

# Highway Flow
plt.subplot(2, 2, 2)
plt.plot(highway_flows, label="Highway Flow", color="green")
plt.title("Highway Flow Over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Flow (vehicles per step)")
plt.legend()

# Ramp Queue
plt.subplot(2, 2, 3)
plt.plot(ramp_queues, label="Ramp Queue", color="red")
plt.title("Ramp Queue Over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Queue Length (vehicles)")
plt.legend()

# Average Speed
plt.subplot(2, 2, 4)
plt.plot(avg_speeds, label="Average Speed", color="blue")
plt.title("Average Speed Over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Speed (m/s)")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Starting episode 1
# No vehicles left, terminating simulation.
# Episode 1 finished with total reward: 369222.53
# Starting episode 2
# No vehicles left, terminating simulation.
# Episode 2 finished with total reward: 363471.34
# Starting episode 3
# No vehicles left, terminating simulation.
# Episode 3 finished with total reward: 365953.94
# Starting episode 4
# No vehicles left, terminating simulation.
# Episode 4 finished with total reward: 364575.30
# Starting episode 5
# No vehicles left, terminating simulation.
# Episode 5 finished with total reward: 367111.11
# Starting episode 6
# No vehicles left, terminating simulation.
# Episode 6 finished with total reward: 366906.52
# Starting episode 7
# No vehicles left, terminating simulation.
# Episode 7 finished with total reward: 365608.82
# Starting episode 8
# No vehicles left, terminating simulation.
# Episode 8 finished with total reward: 367413.74
# Starting episode 9
# No vehicles left, terminating simulation.
# Episode 9 finished with total reward: 368296.92
# Starting episode 10
# No vehicles left, terminating simulation.
# Episode 10 finished with total reward: 368619.94
# Starting episode 11
# No vehicles left, terminating simulation.
# Episode 11 finished with total reward: 363194.17
# Starting episode 12
# No vehicles left, terminating simulation.
# Episode 12 finished with total reward: 367045.81
# Starting episode 13
# No vehicles left, terminating simulation.
# Episode 13 finished with total reward: 368956.76
# Starting episode 14
# No vehicles left, terminating simulation.
# Episode 14 finished with total reward: 368879.25
# Starting episode 15
# No vehicles left, terminating simulation.
# Episode 15 finished with total reward: 362933.85
# Starting episode 16
# No vehicles left, terminating simulation.
# Episode 16 finished with total reward: 367885.62
# Starting episode 17
# No vehicles left, terminating simulation.
# Episode 17 finished with total reward: 368157.67
# Starting episode 18
# No vehicles left, terminating simulation.
# Episode 18 finished with total reward: 367694.42
# Starting episode 19
# No vehicles left, terminating simulation.
# Episode 19 finished with total reward: 368388.58
# Starting episode 20
# No vehicles left, terminating simulation.
# Episode 20 finished with total reward: 368126.95
# Starting episode 21
# No vehicles left, terminating simulation.
# Episode 21 finished with total reward: 366937.73
# Starting episode 22
# No vehicles left, terminating simulation.
# Episode 22 finished with total reward: 368284.94
# Starting episode 23
# No vehicles left, terminating simulation.
# Episode 23 finished with total reward: 367289.42
# Starting episode 24
# No vehicles left, terminating simulation.
# Episode 24 finished with total reward: 365260.29
# Starting episode 25
# No vehicles left, terminating simulation.
# Episode 25 finished with total reward: 368588.03
# Starting episode 26
# No vehicles left, terminating simulation.
# Episode 26 finished with total reward: 366603.25
# Starting episode 27
# No vehicles left, terminating simulation.
# Episode 27 finished with total reward: 366713.57
# Starting episode 28
# No vehicles left, terminating simulation.
# Episode 28 finished with total reward: 368429.09
# Starting episode 29
# No vehicles left, terminating simulation.
# Episode 29 finished with total reward: 365739.38
# Starting episode 30
# No vehicles left, terminating simulation.
# Episode 30 finished with total reward: 367789.13
# Starting episode 31
# No vehicles left, terminating simulation.
# Episode 31 finished with total reward: 366299.25
# Starting episode 32
# No vehicles left, terminating simulation.
# Episode 32 finished with total reward: 368394.07
# Starting episode 33
# No vehicles left, terminating simulation.
# Episode 33 finished with total reward: 369035.93
# Starting episode 34
# No vehicles left, terminating simulation.
# Episode 34 finished with total reward: 371628.70
# Starting episode 35
# No vehicles left, terminating simulation.
# Episode 35 finished with total reward: 363651.23
# Starting episode 36
# No vehicles left, terminating simulation.
# Episode 36 finished with total reward: 365749.19
# Starting episode 37
# No vehicles left, terminating simulation.
# Episode 37 finished with total reward: 368623.21
# Starting episode 38
# No vehicles left, terminating simulation.
# Episode 38 finished with total reward: 367185.43
# Starting episode 39
# No vehicles left, terminating simulation.
# Episode 39 finished with total reward: 368549.62
# Starting episode 40
# No vehicles left, terminating simulation.
# Episode 40 finished with total reward: 365935.08
# Starting episode 41
# No vehicles left, terminating simulation.
# Episode 41 finished with total reward: 367289.22
# Starting episode 42
# No vehicles left, terminating simulation.
# Episode 42 finished with total reward: 371579.11
# Starting episode 43
# No vehicles left, terminating simulation.
# Episode 43 finished with total reward: 376583.48
# Starting episode 44
# No vehicles left, terminating simulation.
# Episode 44 finished with total reward: 372449.64
# Starting episode 45
# No vehicles left, terminating simulation.
# Episode 45 finished with total reward: 368759.27
# Starting episode 46
# No vehicles left, terminating simulation.
# Episode 46 finished with total reward: 375333.42
# Starting episode 47
# No vehicles left, terminating simulation.
# Episode 47 finished with total reward: 371399.74
# Starting episode 48
# No vehicles left, terminating simulation.
# Episode 48 finished with total reward: 371770.81
# Starting episode 49
# No vehicles left, terminating simulation.
# Episode 49 finished with total reward: 367919.06
# Starting episode 50
# No vehicles left, terminating simulation.
# Episode 50 finished with total reward: 366820.48
# Starting episode 51
# No vehicles left, terminating simulation.
# Episode 51 finished with total reward: 372840.26
# Starting episode 52
# No vehicles left, terminating simulation.
# Episode 52 finished with total reward: 372367.52
# Starting episode 53
# No vehicles left, terminating simulation.
# Episode 53 finished with total reward: 372710.60
# Starting episode 54
# No vehicles left, terminating simulation.
# Episode 54 finished with total reward: 369968.49
# Starting episode 55
# No vehicles left, terminating simulation.
# Episode 55 finished with total reward: 370463.36
# Starting episode 56
# No vehicles left, terminating simulation.
# Episode 56 finished with total reward: 371558.25
# Starting episode 57
# No vehicles left, terminating simulation.
# Episode 57 finished with total reward: 372823.61
# Starting episode 58
# No vehicles left, terminating simulation.
# Episode 58 finished with total reward: 369870.39
# Starting episode 59
# No vehicles left, terminating simulation.
# Episode 59 finished with total reward: 367911.26
# Starting episode 60
# No vehicles left, terminating simulation.
# Episode 60 finished with total reward: 370172.71
# Starting episode 61
# No vehicles left, terminating simulation.
# Episode 61 finished with total reward: 371740.20
# Starting episode 62
# No vehicles left, terminating simulation.
# Episode 62 finished with total reward: 372416.76
# Starting episode 63
# No vehicles left, terminating simulation.
# Episode 63 finished with total reward: 368055.45
# Starting episode 64
# No vehicles left, terminating simulation.
# Episode 64 finished with total reward: 369882.57
# Starting episode 65
# No vehicles left, terminating simulation.
# Episode 65 finished with total reward: 368793.90
# Starting episode 66
# No vehicles left, terminating simulation.
# Episode 66 finished with total reward: 373912.09
# Starting episode 67
# No vehicles left, terminating simulation.
# Episode 67 finished with total reward: 366709.12
# Starting episode 68
# No vehicles left, terminating simulation.
# Episode 68 finished with total reward: 369429.05
# Starting episode 69
# No vehicles left, terminating simulation.
# Episode 69 finished with total reward: 368786.20
# Starting episode 70
# No vehicles left, terminating simulation.
# Episode 70 finished with total reward: 370143.06
# Starting episode 71
# No vehicles left, terminating simulation.
# Episode 71 finished with total reward: 366825.66
# Starting episode 72
# No vehicles left, terminating simulation.
# Episode 72 finished with total reward: 367312.68
# Starting episode 73
# No vehicles left, terminating simulation.
# Episode 73 finished with total reward: 368159.91
# Starting episode 74
# No vehicles left, terminating simulation.
# Episode 74 finished with total reward: 371429.60
# Starting episode 75
# No vehicles left, terminating simulation.
# Episode 75 finished with total reward: 370912.00
# Starting episode 76
# No vehicles left, terminating simulation.
# Episode 76 finished with total reward: 369099.23
# Starting episode 77
# No vehicles left, terminating simulation.
# Episode 77 finished with total reward: 374972.13
# Starting episode 78
# No vehicles left, terminating simulation.
# Episode 78 finished with total reward: 372277.50
# Starting episode 79
# No vehicles left, terminating simulation.
# Episode 79 finished with total reward: 370530.19
# Starting episode 80
# No vehicles left, terminating simulation.
# Episode 80 finished with total reward: 370384.71
# Starting episode 81
# No vehicles left, terminating simulation.
# Episode 81 finished with total reward: 369674.59
# Starting episode 82
# No vehicles left, terminating simulation.
# Episode 82 finished with total reward: 371377.80
# Starting episode 83
# No vehicles left, terminating simulation.
# Episode 83 finished with total reward: 368855.00
# Starting episode 84
# No vehicles left, terminating simulation.
# Episode 84 finished with total reward: 372138.74
# Starting episode 85
# No vehicles left, terminating simulation.
# Episode 85 finished with total reward: 373905.68
# Starting episode 86
# No vehicles left, terminating simulation.
# Episode 86 finished with total reward: 367155.41
# Starting episode 87
# No vehicles left, terminating simulation.
# Episode 87 finished with total reward: 369502.97
# Starting episode 88
# No vehicles left, terminating simulation.
# Episode 88 finished with total reward: 367459.86
# Starting episode 89
# No vehicles left, terminating simulation.
# Episode 89 finished with total reward: 370155.16
# Starting episode 90
# No vehicles left, terminating simulation.
# Episode 90 finished with total reward: 369384.61
# Starting episode 91
# No vehicles left, terminating simulation.
# Episode 91 finished with total reward: 372433.78
# Starting episode 92
# No vehicles left, terminating simulation.
# Episode 92 finished with total reward: 370208.85
# Starting episode 93
# No vehicles left, terminating simulation.
# Episode 93 finished with total reward: 370103.54
# Starting episode 94
# No vehicles left, terminating simulation.
# Episode 94 finished with total reward: 370741.18
# Starting episode 95
# No vehicles left, terminating simulation.
# Episode 95 finished with total reward: 370094.37
# Starting episode 96
# No vehicles left, terminating simulation.
# Episode 96 finished with total reward: 372152.87
# Starting episode 97
# No vehicles left, terminating simulation.
# Episode 97 finished with total reward: 372622.26
# Starting episode 98
# No vehicles left, terminating simulation.
# Episode 98 finished with total reward: 371891.05
# Starting episode 99
# No vehicles left, terminating simulation.
# Episode 99 finished with total reward: 372850.29
# Starting episode 100
# No vehicles left, terminating simulation.
# Episode 100 finished with total reward: 372802.87
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

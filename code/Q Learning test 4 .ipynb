# %%
import traci
import numpy as np
import matplotlib.pyplot as plt
import random
from collections import deque

# Hyperparameters
ALPHA = 0.1  # Learning rate
GAMMA = 0.95  # Discount factor
EPSILON = 2  # Initial exploration rate
EPSILON_DECAY = 0.025  # Slow down decay to allow more exploration initially
MIN_EPSILON = 0.05  # A higher minimum epsilon allows more exploration later
NUM_EPISODES = 200
CONVERGENCE_THRESHOLD = 1e-3
REPLAY_BUFFER_SIZE = 1000
BATCH_SIZE = 32

# Initialize Q-table
num_states_traffic = 11
num_states_queue = 11
num_actions = 3
q_table = np.zeros((num_states_traffic, num_states_queue, num_actions))

# Replay buffer for experience replay
replay_buffer = deque(maxlen=REPLAY_BUFFER_SIZE)

# Helper functions
def reset_simulation():
    """Reset the SUMO simulation to the starting point."""
    traci.load(["--net-file", "test1.net.xml", "--route-files", "test1.rou.xml", "--additional-files", "test1.add.xml"])
    return get_state()

def get_state():
    """Retrieve the current state of the system."""
    highway_traffic = min(traci.edge.getLastStepVehicleNumber("E0") / 10, 1)  # Normalize to [0, 1]
    ramp_queue = min(traci.edge.getLastStepVehicleNumber("E2") / 10, 1)  # Normalize to [0, 1]
    traffic_light_phase = traci.trafficlight.getPhase("J1")
    return (highway_traffic, ramp_queue, traffic_light_phase)

def calculate_reward(highway_flow, ramp_queue, avg_speed):
    """Calculate the reward with refined scaling."""
    highway_reward = 10.0 * np.log1p(highway_flow)  # Logarithmic scaling
    speed_reward = 5.0 * avg_speed  # Moderate weight for speed
    queue_penalty = -5.0 * ramp_queue  # Heavier penalty for ramp queue
    reward = highway_reward + speed_reward + queue_penalty
    return reward

def select_action(state, epsilon):
    """Select an action using epsilon-greedy policy with weighted adjustments."""
    if np.random.rand() < epsilon:
        return np.random.choice([0, 1, 2])  # Explore: random action
    else:
        state_indices = (
            max(0, min(int(state[0] * 10), q_table.shape[0] - 1)),
            max(0, min(int(state[1] * 10), q_table.shape[1] - 1)),
            max(0, min(state[2], q_table.shape[2] - 1)),
        )
        q_values = q_table[state_indices[0], state_indices[1], :]
        
        # Debugging: Validate q_values shape
        if q_values.ndim != 1:
            raise ValueError(f"Expected q_values to be 1D, got shape {q_values.shape}. Check state indices: {state_indices}")
        
        weights = [1.2 if i == np.argmax(q_values) else 1.0 for i in range(len(q_values))]
        return random.choices(range(len(q_values)), weights=weights)[0]  # Weighted action selection


    
def update_q_values(state, action, reward, next_state, done, alpha=0.1, gamma=0.95):
    """Update the Q-values using the Q-learning formula."""
    
    # Convert state values to indices (assuming state values are between 0 and 1)
    state_indices = (int(state[0] * 10), int(state[1] * 10), state[2])
    next_state_indices = (int(next_state[0] * 10), int(next_state[1] * 10), next_state[2])

    # Get current Q-value from the Q-table
    current_q = q_table[state_indices[0], state_indices[1], action]
    
    # Max Q-value for next state
    max_next_q = np.max(q_table[next_state_indices[0], next_state_indices[1], :])
    
    # Calculate new Q-value
    new_q = current_q + alpha * (reward + gamma * max_next_q - current_q)
    
    # Update the Q-table
    q_table[state_indices[0], state_indices[1], action] = new_q



def take_action(action):
    """Take the action in the simulation and return the new state, reward, and done flag."""
    traci.trafficlight.setPhase("J1", action)  # Set traffic light phase

    if traci.simulation.getMinExpectedNumber() > 0:  # Check for active vehicles
        traci.simulationStep()
    else:
        print("No vehicles left, terminating simulation.")
        return None, 0, True  # End episode if no vehicles remain

    # Get new state
    next_state = get_state()
    highway_flow = traci.edge.getLastStepVehicleNumber("E0")
    ramp_queue = traci.edge.getLastStepVehicleNumber("E2")
    avg_speed = traci.edge.getLastStepMeanSpeed("E0")  # Average speed on highway
    reward = calculate_reward(highway_flow, ramp_queue, avg_speed)

    done = False
    return next_state, reward, done


def update_q_table(state, action, reward, next_state):
    """Update the Q-table using the Q-learning formula."""
    if next_state is None:
        return

    state_indices = (
        max(0, min(int(state[0] * 10), q_table.shape[0] - 1)),
        max(0, min(int(state[1] * 10), q_table.shape[1] - 1)),
        max(0, min(state[2], q_table.shape[2] - 1))
    )
    next_state_indices = (
        max(0, min(int(next_state[0] * 10), q_table.shape[0] - 1)),
        max(0, min(int(next_state[1] * 10), q_table.shape[1] - 1)),
        max(0, min(next_state[2], q_table.shape[2] - 1))
    )

    max_future_q = np.max(q_table[next_state_indices[0], next_state_indices[1], :])
    current_q = q_table[state_indices[0], state_indices[1], action]
    q_table[state_indices[0], state_indices[1], action] += ALPHA * (reward + GAMMA * max_future_q - current_q)

def replay_experience():
    """Perform experience replay to stabilize learning."""
    if len(replay_buffer) < BATCH_SIZE:
        return

    batch = random.sample(replay_buffer, BATCH_SIZE)
    for state, action, reward, next_state in batch:
        update_q_table(state, action, reward, next_state)

# Run simulation
sumo_binary = "sumo"
sumo_config_file = "test1.sumocfg"
traci.start([sumo_binary, "-c", sumo_config_file])

# Run Simulation with Improved Exploration and Exploitation
cumulative_rewards = []
avg_highway_flows = []
avg_ramp_queues = []
vehicle_speeds = []

for episode in range(NUM_EPISODES):
    print(f"Starting episode {episode + 1}")
    total_reward = 0
    state = reset_simulation()
    done = False

    q_table_prev = q_table.copy()  # Copy for convergence check
    episode_highway_flows = []
    episode_ramp_queues = []
    episode_speeds = []

    while not done:
        if state is None:
            done = True
            break

        action = select_action(state, EPSILON)
        next_state, reward, done = take_action(action)
        total_reward += reward

        if next_state is None:
            done = True
            break

        replay_buffer.append((state, action, reward, next_state))
        
        # Use the new update_q_values function instead of update_q_table
        update_q_values(state, action, reward, next_state, done)

        state = next_state

        # Collect average metrics for plotting
        highway_flow = traci.edge.getLastStepVehicleNumber("E0")
        ramp_queue = traci.edge.getLastStepVehicleNumber("E2")
        avg_speed = traci.edge.getLastStepMeanSpeed("E0")  # Vehicle speed
        episode_highway_flows.append(highway_flow)
        episode_ramp_queues.append(ramp_queue)
        episode_speeds.append(avg_speed)

        replay_experience()  # Perform experience replay


    # Log for each episode
    vehicle_speeds.append(np.mean(episode_speeds))
    avg_highway_flows.append(np.mean(episode_highway_flows))
    avg_ramp_queues.append(np.mean(episode_ramp_queues))

    # Print the episode's metrics
    print(f"Episode {episode + 1} finished with total reward: {total_reward:.2f}")
    print(f"Average Highway Flow: {np.mean(episode_highway_flows):.2f}")
    print(f"Average Ramp Queue: {np.mean(episode_ramp_queues):.2f}")
    print(f"Average Vehicle Speed: {np.mean(episode_speeds):.2f}")
    
    # Convergence Check
    max_change = np.max(np.abs(q_table - q_table_prev))
    if max_change < CONVERGENCE_THRESHOLD:
        print(f"Convergence reached at episode {episode + 1} (Q-table change: {max_change:.6f})")
        break

    # Decay Epsilon
    EPSILON = max(MIN_EPSILON, EPSILON * (1 - EPSILON_DECAY))

    cumulative_rewards.append(total_reward)

traci.close()

# Plot Results
plt.figure(figsize=(12, 6))

# Plot Cumulative Rewards
plt.subplot(1, 2, 1)
plt.plot(cumulative_rewards)
plt.title("Cumulative Rewards Over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Cumulative Reward")

# Plot Average Highway Flows, Ramp Queues, and Vehicle Speeds
plt.subplot(1, 2, 2)
plt.plot(range(NUM_EPISODES), avg_highway_flows, label="Avg Highway Flow", color="green")
plt.plot(range(NUM_EPISODES), avg_ramp_queues, label="Avg Ramp Queue", color="red")
plt.plot(range(NUM_EPISODES), vehicle_speeds, label="Avg Vehicle Speed", color="blue")
plt.title("Traffic Metrics Over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Metrics")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Starting episode 1
# No vehicles left, terminating simulation.
# Episode 1 finished with total reward: 364076.78
# Average Highway Flow: 3.65
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.38
# Starting episode 2
# No vehicles left, terminating simulation.
# Episode 2 finished with total reward: 366539.22
# Average Highway Flow: 3.58
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.48
# Starting episode 3
# No vehicles left, terminating simulation.
# Episode 3 finished with total reward: 365923.39
# Average Highway Flow: 3.58
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.47
# Starting episode 4
# No vehicles left, terminating simulation.
# Episode 4 finished with total reward: 363887.63
# Average Highway Flow: 3.63
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.39
# Starting episode 5
# No vehicles left, terminating simulation.
# Episode 5 finished with total reward: 362698.14
# Average Highway Flow: 3.67
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.38
# Starting episode 6
# No vehicles left, terminating simulation.
# Episode 6 finished with total reward: 363753.70
# Average Highway Flow: 3.66
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.40
# Starting episode 7
# No vehicles left, terminating simulation.
# Episode 7 finished with total reward: 363230.31
# Average Highway Flow: 3.64
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.37
# Starting episode 8
# No vehicles left, terminating simulation.
# Episode 8 finished with total reward: 365960.12
# Average Highway Flow: 3.56
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.49
# Starting episode 9
# No vehicles left, terminating simulation.
# Episode 9 finished with total reward: 366560.59
# Average Highway Flow: 3.59
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.47
# Starting episode 10
# No vehicles left, terminating simulation.
# Episode 10 finished with total reward: 366682.55
# Average Highway Flow: 3.57
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.47
# Starting episode 11
# No vehicles left, terminating simulation.
# Episode 11 finished with total reward: 366628.03
# Average Highway Flow: 3.57
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.48
# Starting episode 12
# No vehicles left, terminating simulation.
# Episode 12 finished with total reward: 365821.67
# Average Highway Flow: 3.61
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.45
# Starting episode 13
# No vehicles left, terminating simulation.
# Episode 13 finished with total reward: 364115.80
# Average Highway Flow: 3.62
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.40
# Starting episode 14
# No vehicles left, terminating simulation.
# Episode 14 finished with total reward: 364741.31
# Average Highway Flow: 3.62
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.42
# Starting episode 15
# No vehicles left, terminating simulation.
# Episode 15 finished with total reward: 363477.72
# Average Highway Flow: 3.65
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.37
# Starting episode 16
# No vehicles left, terminating simulation.
# Episode 16 finished with total reward: 367400.96
# Average Highway Flow: 3.56
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.52
# Starting episode 17
# No vehicles left, terminating simulation.
# Episode 17 finished with total reward: 364130.60
# Average Highway Flow: 3.64
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.37
# Starting episode 18
# No vehicles left, terminating simulation.
# Episode 18 finished with total reward: 360891.69
# Average Highway Flow: 3.71
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.30
# Starting episode 19
# No vehicles left, terminating simulation.
# Episode 19 finished with total reward: 368348.06
# Average Highway Flow: 3.55
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.53
# Starting episode 20
# No vehicles left, terminating simulation.
# Episode 20 finished with total reward: 367281.30
# Average Highway Flow: 3.56
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.48
# Starting episode 21
# No vehicles left, terminating simulation.
# Episode 21 finished with total reward: 365920.64
# Average Highway Flow: 3.58
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.49
# Starting episode 22
# No vehicles left, terminating simulation.
# Episode 22 finished with total reward: 362071.37
# Average Highway Flow: 3.68
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.34
# Starting episode 23
# No vehicles left, terminating simulation.
# Episode 23 finished with total reward: 364650.82
# Average Highway Flow: 3.60
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.44
# Starting episode 24
# No vehicles left, terminating simulation.
# Episode 24 finished with total reward: 363540.53
# Average Highway Flow: 3.63
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.40
# Starting episode 25
# No vehicles left, terminating simulation.
# Episode 25 finished with total reward: 365768.72
# Average Highway Flow: 3.60
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.47
# Starting episode 26
# No vehicles left, terminating simulation.
# Episode 26 finished with total reward: 363306.13
# Average Highway Flow: 3.68
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.36
# Starting episode 27
# No vehicles left, terminating simulation.
# Episode 27 finished with total reward: 365456.50
# Average Highway Flow: 3.59
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.45
# Starting episode 28
# No vehicles left, terminating simulation.
# Episode 28 finished with total reward: 364185.45
# Average Highway Flow: 3.63
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.40
# Starting episode 29
# No vehicles left, terminating simulation.
# Episode 29 finished with total reward: 364413.87
# Average Highway Flow: 3.63
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.40
# Starting episode 30
# No vehicles left, terminating simulation.
# Episode 30 finished with total reward: 366286.86
# Average Highway Flow: 3.57
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.46
# Starting episode 31
# No vehicles left, terminating simulation.
# Episode 31 finished with total reward: 363382.00
# Average Highway Flow: 3.61
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.42
# Starting episode 32
# No vehicles left, terminating simulation.
# Episode 32 finished with total reward: 366015.00
# Average Highway Flow: 3.56
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.51
# Starting episode 33
# No vehicles left, terminating simulation.
# Episode 33 finished with total reward: 368785.26
# Average Highway Flow: 3.53
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.56
# Starting episode 34
# No vehicles left, terminating simulation.
# Episode 34 finished with total reward: 364891.82
# Average Highway Flow: 3.61
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.44
# Starting episode 35
# No vehicles left, terminating simulation.
# Episode 35 finished with total reward: 366375.42
# Average Highway Flow: 3.57
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.49
# Starting episode 36
# No vehicles left, terminating simulation.
# Episode 36 finished with total reward: 367006.45
# Average Highway Flow: 3.57
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.50
# Starting episode 37
# No vehicles left, terminating simulation.
# Episode 37 finished with total reward: 365249.22
# Average Highway Flow: 3.59
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.45
# Starting episode 38
# No vehicles left, terminating simulation.
# Episode 38 finished with total reward: 362938.79
# Average Highway Flow: 3.67
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.37
# Starting episode 39
# No vehicles left, terminating simulation.
# Episode 39 finished with total reward: 367688.54
# Average Highway Flow: 3.55
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.54
# Starting episode 40
# No vehicles left, terminating simulation.
# Episode 40 finished with total reward: 368349.78
# Average Highway Flow: 3.54
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.55
# Starting episode 41
# No vehicles left, terminating simulation.
# Episode 41 finished with total reward: 366595.81
# Average Highway Flow: 3.58
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.52
# Starting episode 42
# No vehicles left, terminating simulation.
# Episode 42 finished with total reward: 370237.99
# Average Highway Flow: 3.52
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.58
# Starting episode 43
# No vehicles left, terminating simulation.
# Episode 43 finished with total reward: 371161.76
# Average Highway Flow: 3.50
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.63
# Starting episode 44
# No vehicles left, terminating simulation.
# Episode 44 finished with total reward: 366346.49
# Average Highway Flow: 3.57
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.48
# Starting episode 45
# No vehicles left, terminating simulation.
# Episode 45 finished with total reward: 370417.26
# Average Highway Flow: 3.50
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.62
# Starting episode 46
# No vehicles left, terminating simulation.
# Episode 46 finished with total reward: 367964.54
# Average Highway Flow: 3.55
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.52
# Starting episode 47
# No vehicles left, terminating simulation.
# Episode 47 finished with total reward: 368665.92
# Average Highway Flow: 3.55
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.55
# Starting episode 48
# No vehicles left, terminating simulation.
# Episode 48 finished with total reward: 368842.55
# Average Highway Flow: 3.54
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.55
# Starting episode 49
# No vehicles left, terminating simulation.
# Episode 49 finished with total reward: 371538.64
# Average Highway Flow: 3.50
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.67
# Starting episode 50
# No vehicles left, terminating simulation.
# Episode 50 finished with total reward: 370915.41
# Average Highway Flow: 3.49
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.65
# Starting episode 51
# No vehicles left, terminating simulation.
# Episode 51 finished with total reward: 368391.95
# Average Highway Flow: 3.54
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.55
# Starting episode 52
# No vehicles left, terminating simulation.
# Episode 52 finished with total reward: 373198.28
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.71
# Starting episode 53
# No vehicles left, terminating simulation.
# Episode 53 finished with total reward: 370617.59
# Average Highway Flow: 3.50
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.62
# Starting episode 54
# No vehicles left, terminating simulation.
# Episode 54 finished with total reward: 367063.38
# Average Highway Flow: 3.56
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.50
# Starting episode 55
# No vehicles left, terminating simulation.
# Episode 55 finished with total reward: 368896.46
# Average Highway Flow: 3.54
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.57
# Starting episode 56
# No vehicles left, terminating simulation.
# Episode 56 finished with total reward: 368768.31
# Average Highway Flow: 3.53
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.58
# Starting episode 57
# No vehicles left, terminating simulation.
# Episode 57 finished with total reward: 367602.28
# Average Highway Flow: 3.56
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.53
# Starting episode 58
# No vehicles left, terminating simulation.
# Episode 58 finished with total reward: 370081.14
# Average Highway Flow: 3.50
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.62
# Starting episode 59
# No vehicles left, terminating simulation.
# Episode 59 finished with total reward: 369931.25
# Average Highway Flow: 3.51
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.60
# Starting episode 60
# No vehicles left, terminating simulation.
# Episode 60 finished with total reward: 371438.38
# Average Highway Flow: 3.47
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.65
# Starting episode 61
# No vehicles left, terminating simulation.
# Episode 61 finished with total reward: 367764.86
# Average Highway Flow: 3.54
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.54
# Starting episode 62
# No vehicles left, terminating simulation.
# Episode 62 finished with total reward: 371160.11
# Average Highway Flow: 3.50
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.64
# Starting episode 63
# No vehicles left, terminating simulation.
# Episode 63 finished with total reward: 368873.58
# Average Highway Flow: 3.53
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.57
# Starting episode 64
# No vehicles left, terminating simulation.
# Episode 64 finished with total reward: 369539.55
# Average Highway Flow: 3.52
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.60
# Starting episode 65
# No vehicles left, terminating simulation.
# Episode 65 finished with total reward: 369274.35
# Average Highway Flow: 3.53
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.58
# Starting episode 66
# No vehicles left, terminating simulation.
# Episode 66 finished with total reward: 370866.91
# Average Highway Flow: 3.51
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.62
# Starting episode 67
# No vehicles left, terminating simulation.
# Episode 67 finished with total reward: 373250.84
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.71
# Starting episode 68
# No vehicles left, terminating simulation.
# Episode 68 finished with total reward: 369980.00
# Average Highway Flow: 3.50
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.61
# Starting episode 69
# No vehicles left, terminating simulation.
# Episode 69 finished with total reward: 372572.70
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.67
# Starting episode 70
# No vehicles left, terminating simulation.
# Episode 70 finished with total reward: 373417.21
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.35
# Average Vehicle Speed: 7.76
# Starting episode 71
# No vehicles left, terminating simulation.
# Episode 71 finished with total reward: 369915.23
# Average Highway Flow: 3.51
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.61
# Starting episode 72
# No vehicles left, terminating simulation.
# Episode 72 finished with total reward: 370928.54
# Average Highway Flow: 3.48
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.66
# Starting episode 73
# No vehicles left, terminating simulation.
# Episode 73 finished with total reward: 369973.12
# Average Highway Flow: 3.51
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.60
# Starting episode 74
# No vehicles left, terminating simulation.
# Episode 74 finished with total reward: 369194.92
# Average Highway Flow: 3.51
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.61
# Starting episode 75
# No vehicles left, terminating simulation.
# Episode 75 finished with total reward: 373849.75
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.75
# Starting episode 76
# No vehicles left, terminating simulation.
# Episode 76 finished with total reward: 369169.36
# Average Highway Flow: 3.53
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.59
# Starting episode 77
# No vehicles left, terminating simulation.
# Episode 77 finished with total reward: 373697.20
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.73
# Starting episode 78
# No vehicles left, terminating simulation.
# Episode 78 finished with total reward: 374009.57
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.75
# Starting episode 79
# No vehicles left, terminating simulation.
# Episode 79 finished with total reward: 372553.99
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.71
# Starting episode 80
# No vehicles left, terminating simulation.
# Episode 80 finished with total reward: 366324.20
# Average Highway Flow: 3.57
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.51
# Starting episode 81
# No vehicles left, terminating simulation.
# Episode 81 finished with total reward: 375313.36
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.79
# Starting episode 82
# No vehicles left, terminating simulation.
# Episode 82 finished with total reward: 371808.87
# Average Highway Flow: 3.49
# Average Ramp Queue: 0.30
# Average Vehicle Speed: 7.64
# Starting episode 83
# No vehicles left, terminating simulation.
# Episode 83 finished with total reward: 372600.55
# Average Highway Flow: 3.47
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.71
# Starting episode 84
# No vehicles left, terminating simulation.
# Episode 84 finished with total reward: 372195.31
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.70
# Starting episode 85
# No vehicles left, terminating simulation.
# Episode 85 finished with total reward: 376101.66
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.83
# Starting episode 86
# No vehicles left, terminating simulation.
# Episode 86 finished with total reward: 376367.06
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.81
# Starting episode 87
# No vehicles left, terminating simulation.
# Episode 87 finished with total reward: 373349.71
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.74
# Starting episode 88
# No vehicles left, terminating simulation.
# Episode 88 finished with total reward: 372770.55
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.70
# Starting episode 89
# No vehicles left, terminating simulation.
# Episode 89 finished with total reward: 369591.18
# Average Highway Flow: 3.51
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.60
# Starting episode 90
# No vehicles left, terminating simulation.
# Episode 90 finished with total reward: 375132.46
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.78
# Starting episode 91
# No vehicles left, terminating simulation.
# Episode 91 finished with total reward: 369473.97
# Average Highway Flow: 3.52
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.59
# Starting episode 92
# No vehicles left, terminating simulation.
# Episode 92 finished with total reward: 370990.65
# Average Highway Flow: 3.48
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.63
# Starting episode 93
# No vehicles left, terminating simulation.
# Episode 93 finished with total reward: 374186.82
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.75
# Starting episode 94
# No vehicles left, terminating simulation.
# Episode 94 finished with total reward: 375474.02
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.81
# Starting episode 95
# No vehicles left, terminating simulation.
# Episode 95 finished with total reward: 376264.26
# Average Highway Flow: 3.38
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.82
# Starting episode 96
# No vehicles left, terminating simulation.
# Episode 96 finished with total reward: 370124.63
# Average Highway Flow: 3.51
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.60
# Starting episode 97
# No vehicles left, terminating simulation.
# Episode 97 finished with total reward: 373229.95
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.71
# Starting episode 98
# No vehicles left, terminating simulation.
# Episode 98 finished with total reward: 376686.86
# Average Highway Flow: 3.37
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.84
# Starting episode 99
# No vehicles left, terminating simulation.
# Episode 99 finished with total reward: 368659.07
# Average Highway Flow: 3.55
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.54
# Starting episode 100
# No vehicles left, terminating simulation.
# Episode 100 finished with total reward: 374800.18
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.77
# Starting episode 101
# No vehicles left, terminating simulation.
# Episode 101 finished with total reward: 371496.06
# Average Highway Flow: 3.50
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.65
# Starting episode 102
# No vehicles left, terminating simulation.
# Episode 102 finished with total reward: 375399.07
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.81
# Starting episode 103
# No vehicles left, terminating simulation.
# Episode 103 finished with total reward: 371865.80
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.69
# Starting episode 104
# No vehicles left, terminating simulation.
# Episode 104 finished with total reward: 376005.73
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.80
# Starting episode 105
# No vehicles left, terminating simulation.
# Episode 105 finished with total reward: 375400.11
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.80
# Starting episode 106
# No vehicles left, terminating simulation.
# Episode 106 finished with total reward: 371543.87
# Average Highway Flow: 3.48
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.67
# Starting episode 107
# No vehicles left, terminating simulation.
# Episode 107 finished with total reward: 370261.65
# Average Highway Flow: 3.49
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.64
# Starting episode 108
# No vehicles left, terminating simulation.
# Episode 108 finished with total reward: 373684.67
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.75
# Starting episode 109
# No vehicles left, terminating simulation.
# Episode 109 finished with total reward: 375790.29
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.80
# Starting episode 110
# No vehicles left, terminating simulation.
# Episode 110 finished with total reward: 373697.71
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.75
# Starting episode 111
# No vehicles left, terminating simulation.
# Episode 111 finished with total reward: 378841.08
# Average Highway Flow: 3.34
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.90
# Starting episode 112
# No vehicles left, terminating simulation.
# Episode 112 finished with total reward: 376033.69
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.82
# Starting episode 113
# No vehicles left, terminating simulation.
# Episode 113 finished with total reward: 377670.86
# Average Highway Flow: 3.37
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.88
# Starting episode 114
# No vehicles left, terminating simulation.
# Episode 114 finished with total reward: 373198.63
# Average Highway Flow: 3.47
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.68
# Starting episode 115
# No vehicles left, terminating simulation.
# Episode 115 finished with total reward: 374396.25
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.75
# Starting episode 116
# No vehicles left, terminating simulation.
# Episode 116 finished with total reward: 373103.88
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.72
# Starting episode 117
# No vehicles left, terminating simulation.
# Episode 117 finished with total reward: 374438.46
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.75
# Starting episode 118
# No vehicles left, terminating simulation.
# Episode 118 finished with total reward: 376682.30
# Average Highway Flow: 3.38
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.83
# Starting episode 119
# No vehicles left, terminating simulation.
# Episode 119 finished with total reward: 374111.12
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.76
# Starting episode 120
# No vehicles left, terminating simulation.
# Episode 120 finished with total reward: 371597.42
# Average Highway Flow: 3.48
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.64
# Starting episode 121
# No vehicles left, terminating simulation.
# Episode 121 finished with total reward: 373797.33
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.72
# Starting episode 122
# No vehicles left, terminating simulation.
# Episode 122 finished with total reward: 376754.94
# Average Highway Flow: 3.38
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.84
# Starting episode 123
# No vehicles left, terminating simulation.
# Episode 123 finished with total reward: 375023.51
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.81
# Starting episode 124
# No vehicles left, terminating simulation.
# Episode 124 finished with total reward: 377723.69
# Average Highway Flow: 3.37
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.85
# Starting episode 125
# No vehicles left, terminating simulation.
# Episode 125 finished with total reward: 377864.60
# Average Highway Flow: 3.37
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.87
# Starting episode 126
# No vehicles left, terminating simulation.
# Episode 126 finished with total reward: 372874.47
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.71
# Starting episode 127
# No vehicles left, terminating simulation.
# Episode 127 finished with total reward: 375420.52
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.81
# Starting episode 128
# No vehicles left, terminating simulation.
# Episode 128 finished with total reward: 374916.59
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.77
# Starting episode 129
# No vehicles left, terminating simulation.
# Episode 129 finished with total reward: 375451.88
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.79
# Starting episode 130
# No vehicles left, terminating simulation.
# Episode 130 finished with total reward: 370889.80
# Average Highway Flow: 3.48
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.65
# Starting episode 131
# No vehicles left, terminating simulation.
# Episode 131 finished with total reward: 376807.93
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.82
# Starting episode 132
# No vehicles left, terminating simulation.
# Episode 132 finished with total reward: 376875.76
# Average Highway Flow: 3.38
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.82
# Starting episode 133
# No vehicles left, terminating simulation.
# Episode 133 finished with total reward: 375362.45
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.78
# Starting episode 134
# No vehicles left, terminating simulation.
# Episode 134 finished with total reward: 374551.45
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.76
# Starting episode 135
# No vehicles left, terminating simulation.
# Episode 135 finished with total reward: 374985.70
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.35
# Average Vehicle Speed: 7.80
# Starting episode 136
# No vehicles left, terminating simulation.
# Episode 136 finished with total reward: 374132.78
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.76
# Starting episode 137
# No vehicles left, terminating simulation.
# Episode 137 finished with total reward: 378177.05
# Average Highway Flow: 3.37
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.87
# Starting episode 138
# No vehicles left, terminating simulation.
# Episode 138 finished with total reward: 374138.40
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.78
# Starting episode 139
# No vehicles left, terminating simulation.
# Episode 139 finished with total reward: 372403.08
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.70
# Starting episode 140
# No vehicles left, terminating simulation.
# Episode 140 finished with total reward: 375074.86
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.76
# Starting episode 141
# No vehicles left, terminating simulation.
# Episode 141 finished with total reward: 377108.48
# Average Highway Flow: 3.38
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.86
# Starting episode 142
# No vehicles left, terminating simulation.
# Episode 142 finished with total reward: 374353.87
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.79
# Starting episode 143
# No vehicles left, terminating simulation.
# Episode 143 finished with total reward: 377373.53
# Average Highway Flow: 3.38
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.87
# Starting episode 144
# No vehicles left, terminating simulation.
# Episode 144 finished with total reward: 372652.18
# Average Highway Flow: 3.47
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.69
# Starting episode 145
# No vehicles left, terminating simulation.
# Episode 145 finished with total reward: 375610.42
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.81
# Starting episode 146
# No vehicles left, terminating simulation.
# Episode 146 finished with total reward: 375386.78
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.82
# Starting episode 147
# No vehicles left, terminating simulation.
# Episode 147 finished with total reward: 374832.63
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.77
# Starting episode 148
# No vehicles left, terminating simulation.
# Episode 148 finished with total reward: 373656.31
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.73
# Starting episode 149
# No vehicles left, terminating simulation.
# Episode 149 finished with total reward: 374235.94
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.74
# Starting episode 150
# No vehicles left, terminating simulation.
# Episode 150 finished with total reward: 371502.71
# Average Highway Flow: 3.47
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.68
# Starting episode 151
# No vehicles left, terminating simulation.
# Episode 151 finished with total reward: 372305.35
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.67
# Starting episode 152
# No vehicles left, terminating simulation.
# Episode 152 finished with total reward: 372240.05
# Average Highway Flow: 3.48
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.68
# Starting episode 153
# No vehicles left, terminating simulation.
# Episode 153 finished with total reward: 377449.34
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.83
# Starting episode 154
# No vehicles left, terminating simulation.
# Episode 154 finished with total reward: 374519.01
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.75
# Starting episode 155
# No vehicles left, terminating simulation.
# Episode 155 finished with total reward: 374376.68
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.78
# Starting episode 156
# No vehicles left, terminating simulation.
# Episode 156 finished with total reward: 377555.14
# Average Highway Flow: 3.36
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.88
# Starting episode 157
# No vehicles left, terminating simulation.
# Episode 157 finished with total reward: 374305.88
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.79
# Starting episode 158
# No vehicles left, terminating simulation.
# Episode 158 finished with total reward: 372183.59
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.67
# Starting episode 159
# No vehicles left, terminating simulation.
# Episode 159 finished with total reward: 375113.84
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.79
# Starting episode 160
# No vehicles left, terminating simulation.
# Episode 160 finished with total reward: 372937.86
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.73
# Starting episode 161
# No vehicles left, terminating simulation.
# Episode 161 finished with total reward: 371416.09
# Average Highway Flow: 3.47
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.68
# Starting episode 162
# No vehicles left, terminating simulation.
# Episode 162 finished with total reward: 376096.34
# Average Highway Flow: 3.40
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.79
# Starting episode 163
# No vehicles left, terminating simulation.
# Episode 163 finished with total reward: 376481.90
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.84
# Starting episode 164
# No vehicles left, terminating simulation.
# Episode 164 finished with total reward: 377309.36
# Average Highway Flow: 3.36
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.88
# Starting episode 165
# No vehicles left, terminating simulation.
# Episode 165 finished with total reward: 375277.26
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.82
# Starting episode 166
# No vehicles left, terminating simulation.
# Episode 166 finished with total reward: 374228.43
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.75
# Starting episode 167
# No vehicles left, terminating simulation.
# Episode 167 finished with total reward: 372949.51
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.71
# Starting episode 168
# No vehicles left, terminating simulation.
# Episode 168 finished with total reward: 372523.53
# Average Highway Flow: 3.47
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.71
# Starting episode 169
# No vehicles left, terminating simulation.
# Episode 169 finished with total reward: 375716.47
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.79
# Starting episode 170
# No vehicles left, terminating simulation.
# Episode 170 finished with total reward: 376584.61
# Average Highway Flow: 3.38
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.85
# Starting episode 171
# No vehicles left, terminating simulation.
# Episode 171 finished with total reward: 375081.58
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.78
# Starting episode 172
# No vehicles left, terminating simulation.
# Episode 172 finished with total reward: 377971.24
# Average Highway Flow: 3.34
# Average Ramp Queue: 0.34
# Average Vehicle Speed: 7.90
# Starting episode 173
# No vehicles left, terminating simulation.
# Episode 173 finished with total reward: 373823.91
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.76
# Starting episode 174
# No vehicles left, terminating simulation.
# Episode 174 finished with total reward: 374886.37
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.78
# Starting episode 175
# No vehicles left, terminating simulation.
# Episode 175 finished with total reward: 377753.16
# Average Highway Flow: 3.37
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.86
# Starting episode 176
# No vehicles left, terminating simulation.
# Episode 176 finished with total reward: 375385.94
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.78
# Starting episode 177
# No vehicles left, terminating simulation.
# Episode 177 finished with total reward: 372953.43
# Average Highway Flow: 3.45
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.70
# Starting episode 178
# No vehicles left, terminating simulation.
# Episode 178 finished with total reward: 373401.32
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.70
# Starting episode 179
# No vehicles left, terminating simulation.
# Episode 179 finished with total reward: 374320.48
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.76
# Starting episode 180
# No vehicles left, terminating simulation.
# Episode 180 finished with total reward: 371366.87
# Average Highway Flow: 3.49
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.65
# Starting episode 181
# No vehicles left, terminating simulation.
# Episode 181 finished with total reward: 373923.04
# Average Highway Flow: 3.44
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.74
# Starting episode 182
# No vehicles left, terminating simulation.
# Episode 182 finished with total reward: 373163.28
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.71
# Starting episode 183
# No vehicles left, terminating simulation.
# Episode 183 finished with total reward: 371740.90
# Average Highway Flow: 3.47
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.67
# Starting episode 184
# No vehicles left, terminating simulation.
# Episode 184 finished with total reward: 377738.22
# Average Highway Flow: 3.38
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.84
# Starting episode 185
# No vehicles left, terminating simulation.
# Episode 185 finished with total reward: 372719.49
# Average Highway Flow: 3.46
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.68
# Starting episode 186
# No vehicles left, terminating simulation.
# Episode 186 finished with total reward: 377022.52
# Average Highway Flow: 3.37
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.85
# Starting episode 187
# No vehicles left, terminating simulation.
# Episode 187 finished with total reward: 376353.03
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.82
# Starting episode 188
# No vehicles left, terminating simulation.
# Episode 188 finished with total reward: 373971.42
# Average Highway Flow: 3.42
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.75
# Starting episode 189
# No vehicles left, terminating simulation.
# Episode 189 finished with total reward: 378129.90
# Average Highway Flow: 3.36
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.88
# Starting episode 190
# No vehicles left, terminating simulation.
# Episode 190 finished with total reward: 378604.34
# Average Highway Flow: 3.36
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.88
# Starting episode 191
# No vehicles left, terminating simulation.
# Episode 191 finished with total reward: 377033.27
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.84
# Starting episode 192
# No vehicles left, terminating simulation.
# Episode 192 finished with total reward: 374704.69
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.76
# Starting episode 193
# No vehicles left, terminating simulation.
# Episode 193 finished with total reward: 379000.88
# Average Highway Flow: 3.34
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.93
# Starting episode 194
# No vehicles left, terminating simulation.
# Episode 194 finished with total reward: 378202.62
# Average Highway Flow: 3.36
# Average Ramp Queue: 0.32
# Average Vehicle Speed: 7.87
# Starting episode 195
# No vehicles left, terminating simulation.
# Episode 195 finished with total reward: 373597.42
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.76
# Starting episode 196
# No vehicles left, terminating simulation.
# Episode 196 finished with total reward: 376140.68
# Average Highway Flow: 3.39
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.83
# Starting episode 197
# No vehicles left, terminating simulation.
# Episode 197 finished with total reward: 374310.76
# Average Highway Flow: 3.43
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.78
# Starting episode 198
# No vehicles left, terminating simulation.
# Episode 198 finished with total reward: 374900.63
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.79
# Starting episode 199
# No vehicles left, terminating simulation.
# Episode 199 finished with total reward: 374870.13
# Average Highway Flow: 3.41
# Average Ramp Queue: 0.33
# Average Vehicle Speed: 7.79
# Starting episode 200
# No vehicles left, terminating simulation.
# Episode 200 finished with total reward: 372298.91
# Average Highway Flow: 3.48
# Average Ramp Queue: 0.31
# Average Vehicle Speed: 7.66
